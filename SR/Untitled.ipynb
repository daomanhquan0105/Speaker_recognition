# %%
import pandas as pd

# %%
df_res=pd.read_csv("res/result.csv",index_col=0)

# %%
df_res
# Out:
#              file_name test_speaker     scores speaker  result
# 0           102-16.wav          102 -31.172211     102       1
# 1            103-9.wav          103 -29.078456     103       1
# 2           111-13.wav          111 -29.724114     111       1
# 3           111-14.wav          111 -29.507839     223       0
# 4           112-11.wav          112 -33.709746     112       1
# ..                 ...          ...        ...     ...     ...
# 278  thanh-sample5.wav        thanh -21.780027   Thanh       0
# 279  thanh-sample6.wav        thanh -21.482826   Thanh       0
# 280  thanh-sample7.wav        thanh -26.143083   Thanh       0
# 281  thanh-sample8.wav        thanh -20.140606   Thanh       0
# 282  thanh-sample9.wav        thanh -23.051322   Thanh       0
#
# [283 rows x 5 columns]

# %%
# df_res.describe()

# %%
df_true=df_res.query('result==1')
df_true
# Out:
#               file_name test_speaker     scores speaker  result
# 0            102-16.wav          102 -31.172211     102       1
# 1             103-9.wav          103 -29.078456     103       1
# 2            111-13.wav          111 -29.724114     111       1
# 4            112-11.wav          112 -33.709746     112       1
# 5            112-12.wav          112 -36.077450     112       1
# ..                  ...          ...        ...     ...     ...
# 250  nguyet-sample5.wav       nguyet -23.269820  nguyet       1
# 251  nguyet-sample6.wav       nguyet -24.341382  nguyet       1
# 252  nguyet-sample7.wav       nguyet -24.360190  nguyet       1
# 253  nguyet-sample8.wav       nguyet -27.883177  nguyet       1
# 254  nguyet-sample9.wav       nguyet -23.757920  nguyet       1
#
# [213 rows x 5 columns]

# %%
df_false=df_res.query('result==0')
df_false
# Out:
#              file_name test_speaker     scores speaker  result
# 3           111-14.wav          111 -29.507839     223       0
# 11          131-32.wav          131 -33.144657    3573       0
# 22          134-48.wav          134 -30.724653     171       0
# 28          144-13.wav          144 -34.994534     112       0
# 75          254-21.wav          254 -33.207464     224       0
# ..                 ...          ...        ...     ...     ...
# 278  thanh-sample5.wav        thanh -21.780027   Thanh       0
# 279  thanh-sample6.wav        thanh -21.482826   Thanh       0
# 280  thanh-sample7.wav        thanh -26.143083   Thanh       0
# 281  thanh-sample8.wav        thanh -20.140606   Thanh       0
# 282  thanh-sample9.wav        thanh -23.051322   Thanh       0
#
# [70 rows x 5 columns]

# %%
70/283
# Out:
# 0.24734982332155478
